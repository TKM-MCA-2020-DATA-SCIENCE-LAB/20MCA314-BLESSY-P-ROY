# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split

# %%
data= pd.read_csv('/content/sample_data/data (1).csv')

# %%
data
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
plt.figure(figsize=[17,9])
sb.countplot(data['diagnosis'].value_counts())
plt.show()

# %%
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
data.drop(['Unnamed: 32','id'],axis=1,inplace=True)

# %%
x = data.drop('diagnosis',axis=1)
y = data.diagnosis

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
y = lb.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=40)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

# %%
import keras

from keras.models import Sequential

from keras.layers import Dense

from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=9,kernel_initializer='he_uniform',activation='relu',input_dim=30))

classifier.add(Dense(units=9,kernel_initializer='he_uniform',activation='relu'))

classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 279
#
#  dense_1 (Dense)             (None, 9)                 90
#
#  dense_2 (Dense)             (None, 1)                 10
#
# =================================================================
# Total params: 379
# Trainable params: 379
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model = classifier.fit(xtrain,ytrain,batch_size=100,epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 4ms/step - loss: 0.7126 - accuracy: 0.6307
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6566 - accuracy: 0.6734
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6074 - accuracy: 0.7186
# Epoch 4/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5605 - accuracy: 0.7387
# Epoch 5/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5186 - accuracy: 0.7588
# Epoch 6/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4823 - accuracy: 0.7864
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4476 - accuracy: 0.8191
# Epoch 8/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4169 - accuracy: 0.8467
# Epoch 9/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3901 - accuracy: 0.8568
# Epoch 10/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3655 - accuracy: 0.8719
# Epoch 11/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3440 - accuracy: 0.8769
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3240 - accuracy: 0.8894
# Epoch 13/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3071 - accuracy: 0.8945
# Epoch 14/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2915 - accuracy: 0.8995
# Epoch 15/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2778 - accuracy: 0.9045
# Epoch 16/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2649 - accuracy: 0.9070
# Epoch 17/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2535 - accuracy: 0.9121
# Epoch 18/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2430 - accuracy: 0.9146
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2333 - accuracy: 0.9196
# Epoch 20/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2240 - accuracy: 0.9246
# Epoch 21/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2159 - accuracy: 0.9296
# Epoch 22/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2080 - accuracy: 0.9296
# Epoch 23/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2010 - accuracy: 0.9322
# Epoch 24/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1941 - accuracy: 0.9372
# Epoch 25/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1881 - accuracy: 0.9397
# Epoch 26/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1823 - accuracy: 0.9397
# Epoch 27/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1770 - accuracy: 0.9397
# Epoch 28/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1721 - accuracy: 0.9422
# Epoch 29/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1677 - accuracy: 0.9447
# Epoch 30/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1633 - accuracy: 0.9497
# Epoch 31/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1595 - accuracy: 0.9497
# Epoch 32/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1556 - accuracy: 0.9497
# Epoch 33/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1520 - accuracy: 0.9497
# Epoch 34/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1489 - accuracy: 0.9497
# Epoch 35/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1457 - accuracy: 0.9497
# Epoch 36/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1431 - accuracy: 0.9497
# Epoch 37/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1403 - accuracy: 0.9497
# Epoch 38/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1379 - accuracy: 0.9523
# Epoch 39/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1355 - accuracy: 0.9523
# Epoch 40/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1333 - accuracy: 0.9523
# Epoch 41/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1312 - accuracy: 0.9548
# Epoch 42/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1291 - accuracy: 0.9548
# Epoch 43/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1271 - accuracy: 0.9548
# Epoch 44/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1252 - accuracy: 0.9548
# Epoch 45/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1234 - accuracy: 0.9548
# Epoch 46/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1214 - accuracy: 0.9548
# Epoch 47/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 0.9548
# Epoch 48/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1179 - accuracy: 0.9548
# Epoch 49/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1162 - accuracy: 0.9573
# Epoch 50/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1147 - accuracy: 0.9573
# Epoch 51/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1131 - accuracy: 0.9573
# Epoch 52/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1115 - accuracy: 0.9573
# Epoch 53/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1100 - accuracy: 0.9573
# Epoch 54/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1084 - accuracy: 0.9573
# Epoch 55/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9598
# Epoch 56/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1056 - accuracy: 0.9598
# Epoch 57/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1042 - accuracy: 0.9598
# Epoch 58/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1028 - accuracy: 0.9598
# Epoch 59/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1015 - accuracy: 0.9598
# Epoch 60/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1001 - accuracy: 0.9623
# Epoch 61/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0987 - accuracy: 0.9623
# Epoch 62/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0973 - accuracy: 0.9623
# Epoch 63/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9648
# Epoch 64/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0946 - accuracy: 0.9648
# Epoch 65/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0934 - accuracy: 0.9648
# Epoch 66/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0922 - accuracy: 0.9648
# Epoch 67/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0911 - accuracy: 0.9648
# Epoch 68/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0899 - accuracy: 0.9648
# Epoch 69/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0887 - accuracy: 0.9648
# Epoch 70/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0876 - accuracy: 0.9673
# Epoch 71/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0866 - accuracy: 0.9673
# Epoch 72/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0855 - accuracy: 0.9673
# Epoch 73/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 0.9673
# Epoch 74/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0834 - accuracy: 0.9698
# Epoch 75/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0823 - accuracy: 0.9724
# Epoch 76/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0813 - accuracy: 0.9724
# Epoch 77/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0802 - accuracy: 0.9724
# Epoch 78/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0793 - accuracy: 0.9724
# Epoch 79/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0784 - accuracy: 0.9724
# Epoch 80/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0774 - accuracy: 0.9724
# Epoch 81/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0765 - accuracy: 0.9724
# Epoch 82/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0756 - accuracy: 0.9724
# Epoch 83/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0749 - accuracy: 0.9724
# Epoch 84/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9724
# Epoch 85/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0732 - accuracy: 0.9749
# Epoch 86/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0725 - accuracy: 0.9749
# Epoch 87/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9749
# Epoch 88/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0710 - accuracy: 0.9749
# Epoch 89/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9749
# Epoch 90/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0696 - accuracy: 0.9749
# Epoch 91/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0689 - accuracy: 0.9749
# Epoch 92/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0682 - accuracy: 0.9749
# Epoch 93/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0674 - accuracy: 0.9749
# Epoch 94/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9774
# Epoch 95/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9774
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0653 - accuracy: 0.9774
# Epoch 97/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9774
# Epoch 98/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 0.9774
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9774
# Epoch 100/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0625 - accuracy: 0.9774

# %%
plt.plot(model.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
