# %% [markdown]
# • Implement a program to scrap the web page of any popular website – suggested
# python package is scrappy (ensure ethical conduct).

# %%
from bs4 import BeautifulSoup# it is a for pulling data out of
import csv
import requests
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
webpage=requests.get("https://www.flipkart.com/home-furnishing/curtains-accessories/curtains/pr?sid=jra,sl5,2va&marketplace=FLIPKART&otracker=nmenu_sub_Home%20%26%20Furniture_0_Curtains")

# %%
webpage
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(webpage.content,"html.parser")

# %%
print(soup.prettify())# fn in beautifulsoup will enable us to ....view how the tags are nested in the document
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.4eab83.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
names=soup.find_all('a',class_='s1Q9rs')

# %%
names
# Out:
# [<a class="s1Q9rs" href="/adimanav-213-36-cm-7-ft-polyester-door-curtain-pack-2/p/itm198f7eb9caa7f?pid=CRNFMKRZKVYP63CC&amp;lid=LSTCRNFMKRZKVYP63CC8YSG8W&amp;marketplace=FLIPKART&amp;store=jra%2Fsl5%2F2va&amp;srno=b_1_1&amp;otracker=nmenu_sub_Home%20%26%20Furniture_0_Curtains&amp;fm=organic&amp;iid=09ff5801-2576-4353-aa22-5dfde4de8c61.CRNFMKRZKVYP63CC.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=awcda5pn280000001644311351123" rel="noopener noreferrer" target="_blank" title="Adimanav 213.36 cm (7 ft) Polyester Door Curtain (Pack Of 2)">Adimanav 213.36 cm (7 ft) Polyester Door Curtain (Pack ...</a>,
# ...

# %%
n=[]
for i in range(0,len(names)):
  n.append(names[i].get_text())#get names only

# %%
n
# Out:
# ['Adimanav 213.36 cm (7 ft) Polyester Door Curtain (Pack ...',
#  'Home Sizzler 153 cm (5 ft) Polyester Window Curtain (Pa...',
#  'Home Sizzler 214 cm (7 ft) Polyester Door Curtain (Pack...',
#  'Adimanav 152.4 cm (5 ft) Polyester Window Curtain (Pack...',
#  'BHUNTL TRADERS 155 cm (5 ft) Velvet Window Curtain Sing...',
#  'BHUNTL TRADERS 212 cm (7 ft) Velvet Door Curtain Single...',
#  'Home Sizzler 214 cm (7 ft) Polyester Door Curtain (Pack...',
#  'Adimanav 152.4 cm (5 ft) Polyester Window Curtain (Pack...',
#  'Guruh Homes 152.4 cm (5 ft) Polyester Window Curtain (P...',
#  'Adimanav 213.36 cm (7 ft) Polyester Door Curtain (Pack ...',
#  'Fashion String 213 cm (7 ft) Polyester Door Curtain (Pa...',
#  'Adimanav 152.4 cm (5 ft) Polyester Window Curtain (Pack...',
#  'SR Collection 214 cm (7 ft) Net Door Curtain (Pack Of 2...',
#  'Guruh Homes 213.74 cm (7 ft) Polyester Door Curtain Sin...',
#  'CHHAVI INDIA 213 cm (7 ft) Polyester Door Curtain (Pack...',
# ...

# %%
len(n)
# Out:
# 40

# %%
price=soup.find_all('div',class_='_30jeq3')

# %%
price
# Out:
# [<div class="_30jeq3">₹289</div>,
#  <div class="_30jeq3">₹349</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹299</div>,
#  <div class="_30jeq3">₹335</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹379</div>,
#  <div class="_30jeq3">₹439</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹214</div>,
#  <div class="_30jeq3">₹370</div>,
#  <div class="_30jeq3">₹156</div>,
#  <div class="_30jeq3">₹348</div>,
#  <div class="_30jeq3">₹315</div>,
#  <div class="_30jeq3">₹439</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹349</div>,
#  <div class="_30jeq3">₹449</div>,
#  <div class="_30jeq3">₹392</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹349</div>,
#  <div class="_30jeq3">₹333</div>,
#  <div class="_30jeq3">₹429</div>,
#  <div class="_30jeq3">₹399</div>,
# ...

# %%
p=[]
for i in range(0,len(price)):
  p.append(price[i].get_text())

# %%
p
# Out:
# ['₹289',
#  '₹349',
#  '₹399',
#  '₹399',
#  '₹299',
#  '₹335',
#  '₹499',
#  '₹399',
#  '₹379',
#  '₹439',
#  '₹499',
#  '₹214',
#  '₹370',
#  '₹156',
#  '₹348',
#  '₹315',
#  '₹439',
#  '₹399',
#  '₹399',
#  '₹349',
#  '₹449',
#  '₹392',
#  '₹399',
#  '₹349',
#  '₹333',
#  '₹429',
#  '₹399',
#  '₹499',
#  '₹389',
#  '₹459',
#  '₹399',
#  '₹363',
#  '₹390',
#  '₹249',
#  '₹499',
#  '₹299',
#  '₹274',
#  '₹449',
#  '₹169',
#  '₹498',
#  '₹169',
#  '₹498',
#  '₹399',
#  '₹399',
#  '₹499']

# %%
dis=soup.find_all('div',class_='_3Ay6Sb')

# %%
dis
# Out:
# [<div class="_3Ay6Sb"><span>51% off</span></div>,
#  <div class="_3Ay6Sb"><span>56% off</span></div>,
#  <div class="_3Ay6Sb"><span>60% off</span></div>,
#  <div class="_3Ay6Sb"><span>50% off</span></div>,
#  <div class="_3Ay6Sb"><span>83% off</span></div>,
#  <div class="_3Ay6Sb"><span>79% off</span></div>,
#  <div class="_3Ay6Sb"><span>58% off</span></div>,
#  <div class="_3Ay6Sb"><span>69% off</span></div>,
#  <div class="_3Ay6Sb"><span>52% off</span></div>,
#  <div class="_3Ay6Sb"><span>68% off</span></div>,
#  <div class="_3Ay6Sb"><span>75% off</span></div>,
#  <div class="_3Ay6Sb"><span>64% off</span></div>,
#  <div class="_3Ay6Sb"><span>76% off</span></div>,
#  <div class="_3Ay6Sb"><span>60% off</span></div>,
#  <div class="_3Ay6Sb"><span>76% off</span></div>,
#  <div class="_3Ay6Sb"><span>47% off</span></div>,
#  <div class="_3Ay6Sb"><span>51% off</span></div>,
#  <div class="_3Ay6Sb"><span>69% off</span></div>,
#  <div class="_3Ay6Sb"><span>69% off</span></div>,
# ...

# %%
d=[]
for i in range(0,len(dis)):
  d.append(dis[i].get_text())

# %%
d
# Out:
# ['51% off',
#  '56% off',
#  '60% off',
#  '50% off',
#  '83% off',
#  '79% off',
#  '58% off',
#  '69% off',
#  '52% off',
#  '68% off',
#  '75% off',
#  '64% off',
#  '76% off',
#  '60% off',
#  '76% off',
#  '47% off',
#  '51% off',
#  '69% off',
#  '69% off',
#  '50% off',
#  '77% off',
#  '50% off',
#  '60% off',
#  '72% off',
#  '79% off',
#  '52% off',
#  '60% off',
#  '75% off',
#  '72% off',
#  '64% off',
#  '42% off',
#  '81% off',
#  '73% off',
#  '58% off',
#  '66% off',
#  '50% off',
#  '67% off',
#  '55% off',
#  '66% off',
#  '44% off',
#  '66% off',
#  '44% off',
#  '42% off',
#  '69% off',
#  '66% off']

# %%
rating=soup.find_all('div',class_='_3LWZlK')

# %%
rating
# Out:
# [<div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
# ...

# %%
r=[]
for i in range(0,len(names)):
  r.append(rating[i].get_text())

# %%
r
# Out:
# ['4.1',
#  '4.3',
#  '4.3',
#  '4',
#  '3.6',
#  '4',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.2',
#  '4.2',
#  '4.1',
#  '4.2',
#  '4',
#  '4.3',
#  '4.2',
#  '4',
#  '4.1',
#  '4.1',
#  '4.2',
#  '3.9',
#  '4.2',
#  '4',
#  '4.2',
#  '4.1',
#  '4.1',
#  '4.3',
#  '3.9',
#  '4.1',
#  '4.2',
#  '4',
#  '4.3',
#  '4.3',
#  '4.2',
#  '4.3',
#  '4',
#  '4']

# %%
len(r)
# Out:
# 40

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df['names']=n

# %%
df['rating']=r

# %%
df
# Out:
#                                                 names rating
# 0   Adimanav 213.36 cm (7 ft) Polyester Door Curta...    4.1
# 1   Home Sizzler 153 cm (5 ft) Polyester Window Cu...    4.3
# 2   Home Sizzler 214 cm (7 ft) Polyester Door Curt...    4.3
# 3   Adimanav 152.4 cm (5 ft) Polyester Window Curt...      4
# 4   BHUNTL TRADERS 155 cm (5 ft) Velvet Window Cur...    3.6
# 5   BHUNTL TRADERS 212 cm (7 ft) Velvet Door Curta...      4
# 6   Home Sizzler 214 cm (7 ft) Polyester Door Curt...    4.2
# 7   Adimanav 152.4 cm (5 ft) Polyester Window Curt...    4.3
# 8   Guruh Homes 152.4 cm (5 ft) Polyester Window C...    4.1
# 9   Adimanav 213.36 cm (7 ft) Polyester Door Curta...    4.3
# 10  Fashion String 213 cm (7 ft) Polyester Door Cu...    4.1
# 11  Adimanav 152.4 cm (5 ft) Polyester Window Curt...    4.1
# 12  SR Collection 214 cm (7 ft) Net Door Curtain (...    4.2
# 13  Guruh Homes 213.74 cm (7 ft) Polyester Door Cu...    4.2
# ...

# %%
df.to_csv('curtain.csv',index=False)

# %%
pd.read_csv("/content/curtain.csv")
# Out:
#                                                 names  rating
# 0   Adimanav 213.36 cm (7 ft) Polyester Door Curta...     4.1
# 1   Home Sizzler 153 cm (5 ft) Polyester Window Cu...     4.3
# 2   Home Sizzler 214 cm (7 ft) Polyester Door Curt...     4.3
# 3   Adimanav 152.4 cm (5 ft) Polyester Window Curt...     4.0
# 4   BHUNTL TRADERS 155 cm (5 ft) Velvet Window Cur...     3.6
# 5   BHUNTL TRADERS 212 cm (7 ft) Velvet Door Curta...     4.0
# 6   Home Sizzler 214 cm (7 ft) Polyester Door Curt...     4.2
# 7   Adimanav 152.4 cm (5 ft) Polyester Window Curt...     4.3
# 8   Guruh Homes 152.4 cm (5 ft) Polyester Window C...     4.1
# 9   Adimanav 213.36 cm (7 ft) Polyester Door Curta...     4.3
# 10  Fashion String 213 cm (7 ft) Polyester Door Cu...     4.1
# 11  Adimanav 152.4 cm (5 ft) Polyester Window Curt...     4.1
# 12  SR Collection 214 cm (7 ft) Net Door Curtain (...     4.2
# 13  Guruh Homes 213.74 cm (7 ft) Polyester Door Cu...     4.2
# ...
